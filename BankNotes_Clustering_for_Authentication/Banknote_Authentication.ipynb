# %% [markdown]
# ### Importing pandas, loading csv file and visualizing it.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
mydata=pd.read_csv("BanknoteAuthentication.csv")
mydata
# Out:
#             V1        V2
# 0     3.621600   8.66610
# 1     4.545900   8.16740
# 2     3.866000  -2.63830
# 3     3.456600   9.52280
# 4     0.329240  -4.45520
# 5     4.368400   9.67180
# 6     3.591200   3.01290
# 7     2.092200  -6.81000
# 8     3.203200   5.75880
# 9     1.535600   9.17720
# 10    1.224700   8.77790
# 11    3.989900  -2.70660
# 12    1.899300   7.66250
# 13   -1.576800  10.84300
# 14    3.404000   8.72610
# 15    4.676500  -3.38950
# 16    2.671900   3.06460
# 17    0.803550   2.84730
# 18    1.447900  -4.87940
# 19    5.242300  11.02720
# 20    5.786700   7.89020
# 21    0.329200  -4.45520
# 22    3.936200  10.16220
# 23    0.935840   8.88550
# 24    4.433800   9.88700
# 25    0.705700  -5.49810
# 26    1.143200  -3.74130
# 27   -0.382140   8.39090
# 28    6.563300   9.81870
# 29    4.890600  -3.35840
# ...        ...       ...
# 1342 -1.747900  -5.82300
# 1343 -0.959230  -6.71280
# 1344  1.345100   0.23589
# 1345  2.227900   4.09510
# 1346  1.257200   4.87310
# ...

# %%
v1=mydata["V1"]
v2=mydata["V2"]
v1_v2=np.column_stack((v1,v2))
mean=np.mean(v1_v2,0)
std_dev=np.std(v1_v2,0)
print(mean)
print(std_dev)
plt.scatter(v1,v2,s=3)
plt.scatter(mean[0],mean[1],s=200,alpha=0.5)
plt.text(mean[0],mean[1],"Mean Value")
# Out:
# [0.43373526 1.92235312]
# [2.84172641 5.86690749]
# Text(0.43373525728862977, 1.9223531209912554, 'Mean Value')

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
kmresult=KMeans(n_clusters=2).fit(v1_v2)
clusters=kmresult.cluster_centers_
plt.scatter(v1,v2,s=3)
# Out:
# C:\Users\Aashish Ghimire\Anaconda3\lib\site-packages\sklearn\utils\validation.py:37: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LARGE_SPARSE_SUPPORTED = LooseVersion(scipy_version) >= '0.14.0'

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
kmresult=KMeans(n_clusters=2).fit(v1_v2)
clusters=kmresult.cluster_centers_

plt.figure(figsize=(10,10))
plt.scatter(v1,v2, c= kmresult.labels_.astype(float), s=20, alpha=0.5)
plt.scatter(clusters[:,0],clusters[:,1],s=1000,alpha=0.5)
plt.xlabel("V1")
plt.ylabel("V2")
print(clusters)
[plt.text(clusters[i][0],clusters[i][1],"k"+str(i+1)) for i in range(2)]

plt.savefig("Resultgraph.png")
# Out:
# [[-0.12376677 -3.45591265]
#  [ 0.86960048  6.12717909]]
